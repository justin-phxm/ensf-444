# %%
pip install wordcloud
# Out:
# Collecting wordcloud
#   Downloading wordcloud-1.9.3-cp311-cp311-win_amd64.whl.metadata (3.5 kB)
# Requirement already satisfied: numpy>=1.6.1 in c:\users\night\miniconda3\lib\site-packages (from wordcloud) (1.26.3)
# Requirement already satisfied: pillow in c:\users\night\miniconda3\lib\site-packages (from wordcloud) (10.2.0)
# Requirement already satisfied: matplotlib in c:\users\night\miniconda3\lib\site-packages (from wordcloud) (3.8.2)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\night\miniconda3\lib\site-packages (from matplotlib->wordcloud) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in c:\users\night\miniconda3\lib\site-packages (from matplotlib->wordcloud) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\night\miniconda3\lib\site-packages (from matplotlib->wordcloud) (4.47.2)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\night\miniconda3\lib\site-packages (from matplotlib->wordcloud) (1.4.5)
# Requirement already satisfied: packaging>=20.0 in c:\users\night\miniconda3\lib\site-packages (from matplotlib->wordcloud) (23.1)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\night\miniconda3\lib\site-packages (from matplotlib->wordcloud) (3.1.1)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\night\miniconda3\lib\site-packages (from matplotlib->wordcloud) (2.8.2)
# Requirement already satisfied: six>=1.5 in c:\users\night\miniconda3\lib\site-packages (from python-dateutil>=2.7->matplotlib->wordcloud) (1.16.0)
# Downloading wordcloud-1.9.3-cp311-cp311-win_amd64.whl (300 kB)
#    ---------------------------------------- 0.0/300.2 kB ? eta -:--:--
#    - -------------------------------------- 10.2/300.2 kB ? eta -:--:--
#    - -------------------------------------- 10.2/300.2 kB ? eta -:--:--
#    --- ----------------------------------- 30.7/300.2 kB 330.3 kB/s eta 0:00:01
#    ----- --------------------------------- 41.0/300.2 kB 330.3 kB/s eta 0:00:01
#    ------------------ ------------------- 143.4/300.2 kB 853.3 kB/s eta 0:00:01
#    ---------------------------------------  297.0/300.2 kB 1.4 MB/s eta 0:00:01
#    ---------------------------------------- 300.2/300.2 kB 1.4 MB/s eta 0:00:00
# Installing collected packages: wordcloud
# Successfully installed wordcloud-1.9.3
# Note: you may need to restart the kernel to use updated packages.

# %%
# DataFrame
import pandas as pd

# Matplot
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

# Scikit-learn
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder
from sklearn.metrics import confusion_matrix, classification_report, accuracy_score
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.feature_extraction.text import CountVectorizer

from sklearn.model_selection import cross_val_predict, StratifiedKFold
from sklearn.feature_selection import SelectKBest, f_classif
from sklearn.linear_model import RidgeClassifier
from sklearn.naive_bayes import MultinomialNB
from sklearn.svm import SVC
from sklearn.pipeline import Pipeline
from sklearn import metrics

# nltk
import nltk
from nltk.corpus import stopwords
from nltk.stem import SnowballStemmer
from nltk.tokenize import word_tokenize
from nltk.probability import FreqDist
nltk.download('punkt')
import string

# spacy
import spacy
# !python -m spacy download en_core_web_sm

# Word2vec
import gensim

# Utility
import re
import numpy as np
import os
from collections import Counter
import logging
import time
import pickle
import itertools

from wordcloud import WordCloud
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\night\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# Collecting en-core-web-sm==3.7.1
#   Downloading https://github.com/explosion/spacy-models/releases/download/en_core_web_sm-3.7.1/en_core_web_sm-3.7.1-py3-none-any.whl (12.8 MB)
#      ---------------------------------------- 0.0/12.8 MB ? eta -:--:--
#      ---------------------------------------- 0.0/12.8 MB ? eta -:--:--
#      ---------------------------------------- 0.0/12.8 MB ? eta -:--:--
#      --------------------------------------- 0.0/12.8 MB 187.9 kB/s eta 0:01:08
#      --------------------------------------- 0.0/12.8 MB 219.4 kB/s eta 0:00:59
#      --------------------------------------- 0.1/12.8 MB 328.6 kB/s eta 0:00:39
#       -------------------------------------- 0.2/12.8 MB 700.2 kB/s eta 0:00:19
#      - -------------------------------------- 0.4/12.8 MB 1.3 MB/s eta 0:00:10
#      -- ------------------------------------- 0.6/12.8 MB 1.9 MB/s eta 0:00:07
#      --- ------------------------------------ 1.0/12.8 MB 2.8 MB/s eta 0:00:05
#      ---- ----------------------------------- 1.4/12.8 MB 3.3 MB/s eta 0:00:04
#      ------ --------------------------------- 1.9/12.8 MB 4.1 MB/s eta 0:00:03
#      ------- -------------------------------- 2.4/12.8 MB 4.6 MB/s eta 0:00:03
#      -------- ------------------------------- 2.7/12.8 MB 4.7 MB/s eta 0:00:03
#      --------- ------------------------------ 3.0/12.8 MB 5.0 MB/s eta 0:00:02
#      ---------- ----------------------------- 3.3/12.8 MB 5.1 MB/s eta 0:00:02
#      ----------- ---------------------------- 3.6/12.8 MB 5.3 MB/s eta 0:00:02
#      ------------- -------------------------- 4.2/12.8 MB 5.7 MB/s eta 0:00:02
#      -------------- ------------------------- 4.6/12.8 MB 5.9 MB/s eta 0:00:02
#      --------------- ------------------------ 5.0/12.8 MB 6.0 MB/s eta 0:00:02
#      ----------------- ---------------------- 5.6/12.8 MB 6.3 MB/s eta 0:00:02
#      ------------------- -------------------- 6.1/12.8 MB 6.5 MB/s eta 0:00:02
#      -------------------- ------------------- 6.6/12.8 MB 6.7 MB/s eta 0:00:01
#      ---------------------- ----------------- 7.1/12.8 MB 7.0 MB/s eta 0:00:01
#      ----------------------- ---------------- 7.6/12.8 MB 7.1 MB/s eta 0:00:01
#      ------------------------ --------------- 7.9/12.8 MB 7.0 MB/s eta 0:00:01
#      --------------------------- ------------ 8.6/12.8 MB 7.5 MB/s eta 0:00:01
#      ---------------------------- ----------- 9.2/12.8 MB 7.6 MB/s eta 0:00:01
#      ----------------------------- ---------- 9.5/12.8 MB 7.7 MB/s eta 0:00:01
#      ------------------------------- -------- 10.0/12.8 MB 7.8 MB/s eta 0:00:01
#      --------------------------------- ------ 10.6/12.8 MB 9.8 MB/s eta 0:00:01
#      --------------------------------- ----- 11.1/12.8 MB 10.2 MB/s eta 0:00:01
#      ----------------------------------- --- 11.7/12.8 MB 10.2 MB/s eta 0:00:01
#      --------------------------------------  12.5/12.8 MB 10.9 MB/s eta 0:00:01
#      --------------------------------------  12.8/12.8 MB 11.3 MB/s eta 0:00:01
#      --------------------------------------- 12.8/12.8 MB 10.9 MB/s eta 0:00:00
# Requirement already satisfied: spacy<3.8.0,>=3.7.2 in c:\users\night\miniconda3\lib\site-packages (from en-core-web-sm==3.7.1) (3.7.4)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.11 in c:\users\night\miniconda3\lib\site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (3.0.12)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in c:\users\night\miniconda3\lib\site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (1.0.5)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in c:\users\night\miniconda3\lib\site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (1.0.10)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in c:\users\night\miniconda3\lib\site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (2.0.8)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in c:\users\night\miniconda3\lib\site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (3.0.9)
# Requirement already satisfied: thinc<8.3.0,>=8.2.2 in c:\users\night\miniconda3\lib\site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (8.2.3)
# Requirement already satisfied: wasabi<1.2.0,>=0.9.1 in c:\users\night\miniconda3\lib\site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (1.1.2)
# Requirement already satisfied: srsly<3.0.0,>=2.4.3 in c:\users\night\miniconda3\lib\site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (2.4.8)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in c:\users\night\miniconda3\lib\site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (2.0.10)
# Requirement already satisfied: weasel<0.4.0,>=0.1.0 in c:\users\night\miniconda3\lib\site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (0.3.4)
# Requirement already satisfied: typer<0.10.0,>=0.3.0 in c:\users\night\miniconda3\lib\site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (0.9.0)
# Requirement already satisfied: smart-open<7.0.0,>=5.2.1 in c:\users\night\miniconda3\lib\site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (6.4.0)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in c:\users\night\miniconda3\lib\site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (4.65.0)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in c:\users\night\miniconda3\lib\site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (2.31.0)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4 in c:\users\night\miniconda3\lib\site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (2.6.4)
# Requirement already satisfied: jinja2 in c:\users\night\miniconda3\lib\site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (3.1.3)
# Requirement already satisfied: setuptools in c:\users\night\miniconda3\lib\site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (68.2.2)
# Requirement already satisfied: packaging>=20.0 in c:\users\night\miniconda3\lib\site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (23.1)
# Requirement already satisfied: langcodes<4.0.0,>=3.2.0 in c:\users\night\miniconda3\lib\site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (3.3.0)
# Requirement already satisfied: numpy>=1.19.0 in c:\users\night\miniconda3\lib\site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (1.26.3)
# Requirement already satisfied: annotated-types>=0.4.0 in c:\users\night\miniconda3\lib\site-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (0.6.0)
# Requirement already satisfied: pydantic-core==2.16.3 in c:\users\night\miniconda3\lib\site-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (2.16.3)
# Requirement already satisfied: typing-extensions>=4.6.1 in c:\users\night\miniconda3\lib\site-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (4.9.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\night\miniconda3\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\night\miniconda3\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\night\miniconda3\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (1.26.18)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\night\miniconda3\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (2023.11.17)
# Requirement already satisfied: blis<0.8.0,>=0.7.8 in c:\users\night\miniconda3\lib\site-packages (from thinc<8.3.0,>=8.2.2->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (0.7.11)
# Requirement already satisfied: confection<1.0.0,>=0.0.1 in c:\users\night\miniconda3\lib\site-packages (from thinc<8.3.0,>=8.2.2->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (0.1.4)
# Requirement already satisfied: colorama in c:\users\night\miniconda3\lib\site-packages (from tqdm<5.0.0,>=4.38.0->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (0.4.6)
# Requirement already satisfied: click<9.0.0,>=7.1.1 in c:\users\night\miniconda3\lib\site-packages (from typer<0.10.0,>=0.3.0->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (8.1.7)
# Requirement already satisfied: cloudpathlib<0.17.0,>=0.7.0 in c:\users\night\miniconda3\lib\site-packages (from weasel<0.4.0,>=0.1.0->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (0.16.0)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\night\miniconda3\lib\site-packages (from jinja2->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (2.1.5)
# ✔ Download and installation successful
# You can now load the package via spacy.load('en_core_web_sm')

# %% [markdown]
# ### Import the dataset and packages
#
# The dataset is downloaded from Kaggle: [link](https://www.kaggle.com/competitions/nlp-getting-started/data?select=train.csv)
#
# You can download it with the following link or download the train.csv file through Kaggle.

# %%
# %%bash
# pip list | grep keras && pip list | grep nltk && pip list | grep spacy
# Out:
# ---------------------------------------------------------------------------
# CalledProcessError                        Traceback (most recent call last)
# Cell In[10], line 1
# ----> 1 get_ipython().run_cell_magic('bash', '', 'pip list | grep keras && pip list | grep nltk && pip list | grep spacy\n')
#
# File ~\AppData\Roaming\Python\Python311\site-packages\IPython\core\interactiveshell.py:2517, in InteractiveShell.run_cell_magic(self, magic_name, line, cell)
#    2515 with self.builtin_trap:
#    2516     args = (magic_arg_s, cell)
# -> 2517     result = fn(*args, **kwargs)
#    2519 # The code below prevents the output from being displayed
#    2520 # when using magics with decorator @output_can_be_silenced
#    2521 # when the last Python token in the expression is a ';'.
#    2522 if getattr(fn, magic.MAGIC_OUTPUT_CAN_BE_SILENCED, False):
#
# File ~\AppData\Roaming\Python\Python311\site-packages\IPython\core\magics\script.py:154, in ScriptMagics._make_script_magic.<locals>.named_script_magic(line, cell)
#     152 else:
#     153     line = script
# --> 154 return self.shebang(line, cell)
#
# File ~\AppData\Roaming\Python\Python311\site-packages\IPython\core\magics\script.py:314, in ScriptMagics.shebang(self, line, cell)
#     309 if args.raise_error and p.returncode != 0:
#     310     # If we get here and p.returncode is still None, we must have
#     311     # killed it but not yet seen its return code. We don't wait for it,
#     312     # in case it's stuck in uninterruptible sleep. -9 = SIGKILL
#     313     rc = p.returncode or -9
# --> 314     raise CalledProcessError(rc, cell)
#
# CalledProcessError: Command 'b'pip list | grep keras && pip list | grep nltk && pip list | grep spacy\n'' returned non-zero exit status 1.

# %%
# !wget -O data.csv https://www.dropbox.com/scl/fi/70e8lr0rsfx5crpmoxj8w/train_ensf.csv?rlkey=4s7p9dpm4fl9hnxiqtrmf2l7z&dl=0
# Out:
# 'wget' is not recognized as an internal or external command,
# operable program or batch file.
# 'dl' is not recognized as an internal or external command,
# operable program or batch file.

# %% [markdown]
# **Task**:
#
# You are predicting whether a given tweet is about a real disaster or not. If so, predict a 1. If not, predict a 0.
#
# **Columns**:
#
# id - a unique identifier for each tweet
#
# text - the text of the tweet
#
# location - the location the tweet was sent from (may be blank)
#
# keyword - a particular keyword from the tweet (may be blank)
#
# target - in train.csv only, this denotes whether a tweet is about a real disaster (1) or not (0)

# %%
# read the dataset
df = pd.read_csv("data.csv")

# %%
# how long is df?
len(df)
# Out:
# 7613

# %%
# look at the head
df.head()
# Out:
#    id keyword location                                               text  \
# 0   1     NaN      NaN  Our Deeds are the Reason of this #earthquake M...
# 1   4     NaN      NaN             Forest fire near La Ronge Sask. Canada
# 2   5     NaN      NaN  All residents asked to 'shelter in place' are ...
# 3   6     NaN      NaN  13,000 people receive #wildfires evacuation or...
# 4   7     NaN      NaN  Just got sent this photo from Ruby #Alaska as ...
#
#    target
# 0       1
# 1       1
# 2       1
# 3       1
# 4       1

# %%
# find the unique values in target
df.target.unique()
# Out:
# array([1, 0], dtype=int64)

# %%
# create a column that has the name of the label instead of its digit call it label
decode_map = {0: "not_disasterous", 1: "disasterous"}
def decode_sentiment(label):
    return decode_map[int(label)]

df.loc[:, 'label'] = df.target.apply(lambda x: decode_sentiment(x))

# %%
# check the null values
print('null values of each field:\n', df.isnull().sum())
# Out:
# null values of each field:
#  id             0
# keyword       61
# location    2533
# text           0
# target         0
# label          0
# dtype: int64

# %%
# fill keyword and location with 'no_key' and 'no_location'
df.keyword.fillna('no_keyword', inplace = True)
df.location.fillna('no_location', inplace = True)
# Out:
# C:\Users\night\AppData\Local\Temp\ipykernel_11872\3511661961.py:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df.keyword.fillna('no_keyword', inplace = True)
# C:\Users\night\AppData\Local\Temp\ipykernel_11872\3511661961.py:3: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df.location.fillna('no_location', inplace = True)

# %%
# visualize the number of negative and positive examples
target_cnt = Counter(df.target)

plt.figure(figsize=(16,8))
plt.bar(target_cnt.keys(), target_cnt.values())
plt.title("Dataset labels distribuition")
# change the x-axis labels
plt.xticks([0, 1], ['not_disasterous', 'disasterous'])
# Out:
# ([<matplotlib.axis.XTick at 0x2a7f1095f90>,
#   <matplotlib.axis.XTick at 0x2a7f1054f10>],
#  [Text(0, 0, 'not_disasterous'), Text(1, 0, 'disasterous')])

# %%
# what are the top 30 locations in the dataset

top_30 = df.groupby(['location']).count().text.sort_values(ascending = False)[:30]

# plot the top 30

plt.figure(figsize = (6,10))
sns.barplot(x = top_30, y = top_30.index);
plt.xlabel('number of tweets');

# %% [markdown]
# ### Preprocessing

# %%
def preprocess(text:str) -> str:

    # lower case the words
    text = text.lower()

    # remove hyperlinks
    text = re.sub(r"\S*https?:\S*", "", text)

    # remove mentions and hashtags
    text = re.sub(r'[@#]\w*\_*' , '', text)

    # substitute patterns with their correct representation to remove
    rep_character_entity_refrences = {"&gt;": ">", "&lt;":"<",
                                      "&amp;": "&"}

    for k,v in rep_character_entity_refrences.items():
        text = re.sub(k, v, text)

    return text

df.loc[:, 'cleaned_text'] = df.loc[:, 'text'].apply(lambda x: preprocess(x))

# %%
df
# Out:
#          id     keyword     location  \
# 0         1  no_keyword  no_location
# 1         4  no_keyword  no_location
# 2         5  no_keyword  no_location
# 3         6  no_keyword  no_location
# 4         7  no_keyword  no_location
# ...     ...         ...          ...
# 7608  10869  no_keyword  no_location
# 7609  10870  no_keyword  no_location
# 7610  10871  no_keyword  no_location
# 7611  10872  no_keyword  no_location
# 7612  10873  no_keyword  no_location
#
#                                                    text  target        label  \
# 0     Our Deeds are the Reason of this #earthquake M...       1  disasterous
# 1                Forest fire near La Ronge Sask. Canada       1  disasterous
# 2     All residents asked to 'shelter in place' are ...       1  disasterous
# 3     13,000 people receive #wildfires evacuation or...       1  disasterous
# 4     Just got sent this photo from Ruby #Alaska as ...       1  disasterous
# ...                                                 ...     ...          ...
# 7608  Two giant cranes holding a bridge collapse int...       1  disasterous
# 7609  @aria_ahrary @TheTawniest The out of control w...       1  disasterous
# 7610  M1.94 [01:04 UTC]?5km S of Volcano Hawaii. htt...       1  disasterous
# 7611  Police investigating after an e-bike collided ...       1  disasterous
# 7612  The Latest: More Homes Razed by Northern Calif...       1  disasterous
#
#                                            cleaned_text
# 0     our deeds are the reason of this  may allah fo...
# 1                forest fire near la ronge sask. canada
# 2     all residents asked to 'shelter in place' are ...
# 3     13,000 people receive  evacuation orders in ca...
# 4     just got sent this photo from ruby  as smoke f...
# ...                                                 ...
# 7608  two giant cranes holding a bridge collapse int...
# 7609    the out of control wild fires in california ...
# 7610        m1.94 [01:04 utc]?5km s of volcano hawaii.
# 7611  police investigating after an e-bike collided ...
# 7612  the latest: more homes razed by northern calif...
#
# [7613 rows x 7 columns]

# %% [markdown]
# NLTK (Natural Language Toolkit) and spaCy are two popular libraries used for NLP tasks in Python.
#
# They both provide lists of stopwords for various languages, including English.
#
# stopwords are common words that are often filtered out from text during preprocessing because they are considered to have little or no significance. Examples of NLTK English stopwords include "the," "is," "and," "but," etc.

# %%
# nltk stopwords
nltk.download('stopwords')
nltk_stopwords = stopwords.words('english')

# spacy stopwords
nlp = spacy.load("en_core_web_sm")
spacy_stopwords = list(nlp.Defaults.stop_words.copy())

words_to_remove =  ['absolutely', "actually"]

all_stopwords = set(
    nltk_stopwords + spacy_stopwords + words_to_remove
    )

def remove_st(text:str) -> str:

    # Remove stopwords
    filtered_words = [word for word in text.split() if word not in all_stopwords]

    # Join the filtered words back into a sentence
    filtered_text = ' '.join(filtered_words)

    return filtered_text

# apply the remove st on cleaned_text
df.loc[:, 'cleaned_text_no_st'] = df.loc[:, 'cleaned_text'].apply(lambda x: remove_st(x))
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\night\AppData\Roaming\nltk_data...
# [nltk_data]   Unzipping corpora\stopwords.zip.

# %%
df
# Out:
#          id     keyword     location  \
# 0         1  no_keyword  no_location
# 1         4  no_keyword  no_location
# 2         5  no_keyword  no_location
# 3         6  no_keyword  no_location
# 4         7  no_keyword  no_location
# ...     ...         ...          ...
# 7608  10869  no_keyword  no_location
# 7609  10870  no_keyword  no_location
# 7610  10871  no_keyword  no_location
# 7611  10872  no_keyword  no_location
# 7612  10873  no_keyword  no_location
#
#                                                    text  target        label  \
# 0     Our Deeds are the Reason of this #earthquake M...       1  disasterous
# 1                Forest fire near La Ronge Sask. Canada       1  disasterous
# 2     All residents asked to 'shelter in place' are ...       1  disasterous
# 3     13,000 people receive #wildfires evacuation or...       1  disasterous
# 4     Just got sent this photo from Ruby #Alaska as ...       1  disasterous
# ...                                                 ...     ...          ...
# 7608  Two giant cranes holding a bridge collapse int...       1  disasterous
# 7609  @aria_ahrary @TheTawniest The out of control w...       1  disasterous
# 7610  M1.94 [01:04 UTC]?5km S of Volcano Hawaii. htt...       1  disasterous
# 7611  Police investigating after an e-bike collided ...       1  disasterous
# 7612  The Latest: More Homes Razed by Northern Calif...       1  disasterous
#
#                                            cleaned_text  \
# 0     our deeds are the reason of this  may allah fo...
# 1                forest fire near la ronge sask. canada
# 2     all residents asked to 'shelter in place' are ...
# 3     13,000 people receive  evacuation orders in ca...
# 4     just got sent this photo from ruby  as smoke f...
# ...                                                 ...
# 7608  two giant cranes holding a bridge collapse int...
# 7609    the out of control wild fires in california ...
# 7610        m1.94 [01:04 utc]?5km s of volcano hawaii.
# 7611  police investigating after an e-bike collided ...
# 7612  the latest: more homes razed by northern calif...
#
#                                      cleaned_text_no_st
# 0                            deeds reason allah forgive
# 1                forest fire near la ronge sask. canada
# 2     residents asked 'shelter place' notified offic...
# 3     13,000 people receive evacuation orders califo...
# 4                got sent photo ruby smoke pours school
# ...                                                 ...
# 7608  giant cranes holding bridge collapse nearby homes
# 7609  control wild fires california northern state. ...
# 7610              m1.94 [01:04 utc]?5km volcano hawaii.
# 7611  police investigating e-bike collided car littl...
# 7612  latest: homes razed northern california wildfi...
#
# [7613 rows x 8 columns]

# %%
def remove_punctuation_and_digits(text:str) -> str:

    # Remove punctuations
    text = re.sub(r'[^\w\s]', '', text)

    # Remove digits
    text = re.sub(r'\d', '', text)

    # removes all single letters surrounded with space except letters I and a
    text = re.sub(r'(?:^|\s)(?![ia])[a-z] +', ' ', text)

    return text

# %%
df.loc[:, 'cleaned_text'] = df.loc[:, 'cleaned_text'].apply(lambda x: remove_punctuation_and_digits(x))
df.loc[:, 'cleaned_text_no_st'] = df.loc[:, 'cleaned_text_no_st'].apply(lambda x: remove_punctuation_and_digits(x))

# %%
df
# Out:
#          id     keyword     location  \
# 0         1  no_keyword  no_location
# 1         4  no_keyword  no_location
# 2         5  no_keyword  no_location
# 3         6  no_keyword  no_location
# 4         7  no_keyword  no_location
# ...     ...         ...          ...
# 7608  10869  no_keyword  no_location
# 7609  10870  no_keyword  no_location
# 7610  10871  no_keyword  no_location
# 7611  10872  no_keyword  no_location
# 7612  10873  no_keyword  no_location
#
#                                                    text  target        label  \
# 0     Our Deeds are the Reason of this #earthquake M...       1  disasterous
# 1                Forest fire near La Ronge Sask. Canada       1  disasterous
# 2     All residents asked to 'shelter in place' are ...       1  disasterous
# 3     13,000 people receive #wildfires evacuation or...       1  disasterous
# 4     Just got sent this photo from Ruby #Alaska as ...       1  disasterous
# ...                                                 ...     ...          ...
# 7608  Two giant cranes holding a bridge collapse int...       1  disasterous
# 7609  @aria_ahrary @TheTawniest The out of control w...       1  disasterous
# 7610  M1.94 [01:04 UTC]?5km S of Volcano Hawaii. htt...       1  disasterous
# 7611  Police investigating after an e-bike collided ...       1  disasterous
# 7612  The Latest: More Homes Razed by Northern Calif...       1  disasterous
#
#                                            cleaned_text  \
# 0     our deeds are the reason of this  may allah fo...
# 1                 forest fire near la ronge sask canada
# 2     all residents asked to shelter in place are be...
# 3      people receive  evacuation orders in california
# 4     just got sent this photo from ruby  as smoke f...
# ...                                                 ...
# 7608  two giant cranes holding a bridge collapse int...
# 7609    the out of control wild fires in california ...
# 7610                           utckm of volcano hawaii
# 7611  police investigating after an ebike collided w...
# 7612  the latest more homes razed by northern califo...
#
#                                      cleaned_text_no_st
# 0                            deeds reason allah forgive
# 1                 forest fire near la ronge sask canada
# 2     residents asked shelter place notified officer...
# 3           people receive evacuation orders california
# 4                got sent photo ruby smoke pours school
# ...                                                 ...
# 7608  giant cranes holding bridge collapse nearby homes
# 7609  control wild fires california northern state t...
# 7610                               utckm volcano hawaii
# 7611  police investigating ebike collided car little...
# 7612  latest homes razed northern california wildfir...
#
# [7613 rows x 8 columns]

# %% [markdown]
# A word cloud is a visual representation of text data, where the size of each word indicates its frequency or importance in the text.
#
# Word clouds are often used to quickly and visually summarize the content of a large amount of text data.
#
# They can help identify common themes, topics, or keywords within the text.

# %%
# build a word cloud for target == 0

# Combine all text from the specified column into a single string
text = ' '.join(df[df.target==0]['cleaned_text_no_st'])

# Generate the word cloud
wordcloud = WordCloud(width=800, height=400, background_color='white').generate(text)

# Display the word cloud using matplotlib
plt.figure(figsize=(10, 5))
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis('off')  # Turn off axis labels
plt.show()

# %%
# build a word cloud for target == 1

# Combine all text from the specified column into a single string
text = ' '.join(df[df.target==1]['cleaned_text_no_st'])

# Generate the word cloud
wordcloud = WordCloud(width=800, height=400, background_color='white').generate(text)

# Display the word cloud using matplotlib
plt.figure(figsize=(10, 5))
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis('off')  # Turn off axis labels
plt.show()

# %% [markdown]
# Tokenizing is the process of breaking down a text into smaller units, such as words or sentences, called tokens.
#
# Tokenization is an essential step in NLP tasks because it allows the text to be processed at a more granular level.

# %%
# view the most frequent words for target == 1

# Tokenize the text in the specified column
tokens = []
for text in df[df.target==1]['cleaned_text_no_st']:
    tokens.extend(word_tokenize(text))

# Calculate the frequency distribution of tokens
freq_dist = FreqDist(tokens)

# Display the most frequent words and their counts
most_common_words = freq_dist.most_common(10)
print("Most frequent words:")
for word, count in most_common_words:
    print(f"{word}: {count}")

# Plot a bar chart of the frequency distribution
freq_dist.plot(20, cumulative=False)
plt.show()
# Out:
# Most frequent words:
# fire: 177
# suicide: 110
# disaster: 110
# california: 107
# police: 106
# people: 104
# killed: 92
# like: 92
# pm: 89
# fires: 85

# %% [markdown]
# ### Prediction with RidgeClassifier, NaiveBayes, LinearSVM
# Here we'll use counter vectorizer to specify one column for each word in the tweets and use it as a feature for prediction. If a tweet has a word, the column specife to that word will have the value of 1 (or more based on how many times that word has repeated in that tweet.)
#
# As for the models, we chose these three because they can predict sparse data fast. You can go on and do gridsearch on them and find the best parameters for each.

# %%
# create a CountVectorizer function
counter_vectorizer = CountVectorizer(min_df=10, dtype=np.int8)

# fit and transform the df
counter_vectorizer.fit(df.cleaned_text_no_st)
transformed_rows = counter_vectorizer.transform(df.cleaned_text_no_st).todense()

# %%
transformed_rows.shape
# Out:
# (7613, 1254)

# %%
transformed_rows.nbytes // 1e6
# Out:
# 9.0

# %%
# use the three algorithms and build cross validation to assess their performance
# make sure to create one pipeline with a feature selection algorithm inside it as well
import warnings
warnings.filterwarnings("ignore", message="Features.*", category=UserWarning)
warnings.filterwarnings("ignore", message="invalid.*", category=RuntimeWarning)

# Assuming you have your target variable 'y' and features 'transformed_rows'
# Example data
np.random.seed(42)
X = np.asarray(transformed_rows)
y = df.target
# y = df.target.values.reshape(-1, 1)

# Create a pipeline with feature selection and classifiers
ridge_pipeline = Pipeline([
    ('feature_selection', SelectKBest(f_classif, k=100)),  # Adjust k as needed
    ('classifier', RidgeClassifier())
])

naive_bayes_pipeline = Pipeline([
    ('feature_selection', SelectKBest(f_classif, k=100)),
    ('classifier', MultinomialNB())
])

linear_svm_pipeline = Pipeline([
    ('feature_selection', SelectKBest(f_classif, k=100)),
    ('classifier', SVC(kernel='linear'))
])

# Define the classifiers
classifiers = {
    'Ridge Classifier': ridge_pipeline,
    'Naive Bayes': naive_bayes_pipeline,
    'Linear SVM': linear_svm_pipeline
}

# Perform cross-validation and compare results
cv = StratifiedKFold(n_splits=5, shuffle=True, random_state=42)

for name, clf in classifiers.items():
    y_pred = cross_val_predict(clf, X, y, cv=cv)

    # Print confusion matrix and metrics
    print(f'\nResults for {name}:')
    print('Confusion Matrix:')
    print(metrics.confusion_matrix(y, y_pred))

    accuracy = metrics.accuracy_score(y, y_pred)
    precision = metrics.precision_score(y, y_pred)
    recall = metrics.recall_score(y, y_pred)
    f1 = metrics.f1_score(y, y_pred)

    print(f'Accuracy: {accuracy:.2f}')
    print(f'Precision: {precision:.2f}')
    print(f'Recall: {recall:.2f}')
    print(f'F1 Score: {f1:.2f}')
# Out:
# Results for Ridge Classifier:
# Confusion Matrix:
# [[3989  353]
#  [1738 1533]]
# Accuracy: 0.73
# Precision: 0.81
# Recall: 0.47
# F1 Score: 0.59
#
# Results for Naive Bayes:
# Confusion Matrix:
# [[4131  211]
#  [2024 1247]]
# Accuracy: 0.71
# Precision: 0.86
# Recall: 0.38
# F1 Score: 0.53
#
# Results for Linear SVM:
# Confusion Matrix:
# [[3948  394]
#  [1702 1569]]
# Accuracy: 0.72
# Precision: 0.80
# Recall: 0.48
# F1 Score: 0.60

# %% [markdown]
# ***Your Turn***

# %% [markdown]
# The dataset is downloaded from Kaggle: [link](https://www.kaggle.com/datasets/emineyetm/fake-news-detection-datasets)

# %%
df_true = pd.read_csv('content/True.csv', encoding='utf-8')
df_fake = pd.read_csv('content/Fake.csv', encoding='utf-8')

df_fake["target"] = 0
df_true["target"] = 1

df = pd.concat([df_fake,df_true], axis = 0).drop(["title", "subject","date"], axis = 1).sample(frac = 1)

df.isnull().sum()
# Out:
# text      0
# target    0
# dtype: int64

# %%
df = df.reset_index(drop=True)
df.head()
# Out:
#                                                 text  target
# 0  LONDON (Reuters) - Britain s government said o...       1
# 1  WASHINGTON (Reuters) - Director of National In...       1
# 2  Former Navy SEAL and GOP Rep. Scott Taylor, R-...       0
# 3  WASHINGTON (Reuters) - The White House on Thur...       1
# 4  BERN (Reuters) - European and African minister...       1

# %%
def preprocess(text:str) -> str:

    # lower case the words
    text = text.lower()
    # remove hyperlinks
    text = re.sub(r"\S*https?:\S*", "", text)
    # remove mentions and hashtags
    text = re.sub(r'[@#]\w*\_*' , '', text)
    # substitute patterns with their correct representation to remove
    rep_character_entity_refrences = {"&gt;": ">", "&lt;":"<",
                                      "&amp;": "&"}
    for k,v in rep_character_entity_refrences.items():
        text = re.sub(k, v, text)
    return text

df.loc[:, 'cleaned_text'] = df.loc[:, 'text'].apply(lambda x: preprocess(x))

# %%
df
# Out:
#                                                     text  target  \
# 0      LONDON (Reuters) - Britain s government said o...       1
# 1      WASHINGTON (Reuters) - Director of National In...       1
# 2      Former Navy SEAL and GOP Rep. Scott Taylor, R-...       0
# 3      WASHINGTON (Reuters) - The White House on Thur...       1
# 4      BERN (Reuters) - European and African minister...       1
# ...                                                  ...     ...
# 44893  NAIROBI (Reuters) - Burundi s main opposition ...       1
# 44894  This isn t just any church organization, this ...       0
# 44895  Miss Universe 1996 Alicia Machado is now an Am...       0
# 44896                                                          0
# 44897  LONDON/TOKYO (Reuters) - British Prime Ministe...       1
#
#                                             cleaned_text
# 0      london (reuters) - britain s government said o...
# 1      washington (reuters) - director of national in...
# 2      former navy seal and gop rep. scott taylor, r-...
# 3      washington (reuters) - the white house on thur...
# 4      bern (reuters) - european and african minister...
# ...                                                  ...
# 44893  nairobi (reuters) - burundi s main opposition ...
# 44894  this isn t just any church organization, this ...
# 44895  miss universe 1996 alicia machado is now an am...
# 44896
# 44897  london/tokyo (reuters) - british prime ministe...
#
# [44898 rows x 3 columns]

# %%
# nltk stopwords
nltk.download('stopwords')
nltk_stopwords = stopwords.words('english')

# spacy stopwords
nlp = spacy.load("en_core_web_sm")
spacy_stopwords = list(nlp.Defaults.stop_words.copy())


words_to_remove =  ['absolutely', "actually"]

all_stopwords = set(
    nltk_stopwords + spacy_stopwords + words_to_remove
    )

def remove_st(text:str) -> str:

    # Remove stopwords
    filtered_words = [word for word in text.split() if word not in all_stopwords]
    # Join the filtered words back into a sentence
    filtered_text = ' '.join(filtered_words)

    return filtered_text
df.loc[:, 'cleaned_text_no_st'] = df.loc[:, 'cleaned_text'].apply(lambda x: remove_st(x))
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\night\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
df
# Out:
#                                                     text  target  \
# 0      LONDON (Reuters) - Britain s government said o...       1
# 1      WASHINGTON (Reuters) - Director of National In...       1
# 2      Former Navy SEAL and GOP Rep. Scott Taylor, R-...       0
# 3      WASHINGTON (Reuters) - The White House on Thur...       1
# 4      BERN (Reuters) - European and African minister...       1
# ...                                                  ...     ...
# 44893  NAIROBI (Reuters) - Burundi s main opposition ...       1
# 44894  This isn t just any church organization, this ...       0
# 44895  Miss Universe 1996 Alicia Machado is now an Am...       0
# 44896                                                          0
# 44897  LONDON/TOKYO (Reuters) - British Prime Ministe...       1
#
#                                             cleaned_text  \
# 0      london (reuters) - britain s government said o...
# 1      washington (reuters) - director of national in...
# 2      former navy seal and gop rep. scott taylor, r-...
# 3      washington (reuters) - the white house on thur...
# 4      bern (reuters) - european and african minister...
# ...                                                  ...
# 44893  nairobi (reuters) - burundi s main opposition ...
# 44894  this isn t just any church organization, this ...
# 44895  miss universe 1996 alicia machado is now an am...
# 44896
# 44897  london/tokyo (reuters) - british prime ministe...
#
#                                       cleaned_text_no_st
# 0      london (reuters) - britain government said thu...
# 1      washington (reuters) - director national intel...
# 2      navy seal gop rep. scott taylor, r-va., body-s...
# 3      washington (reuters) - white house thursday th...
# 4      bern (reuters) - european african ministers ag...
# ...                                                  ...
# 44893  nairobi (reuters) - burundi main opposition gr...
# 44894  church organization, church organization takes...
# 44895  miss universe 1996 alicia machado american cit...
# 44896
# 44897  london/tokyo (reuters) - british prime ministe...
#
# [44898 rows x 4 columns]

# %%
def remove_punctuation_and_digits(text:str) -> str:

    # Remove punctuations
    text = re.sub(r'[^\w\s]', '', text)
    # Remove digits
    text = re.sub(r'\d', '', text)
    # removes all single letters surrounded with space except letters I and a
    text = re.sub(r'(?:^|\s)(?![ia])[a-z] +', ' ', text)
    
    return text

# %%
# apply preprocessing function
df.loc[:, 'cleaned_text'] = df.loc[:, 'text'].apply(lambda x: preprocess(x))

# apply the remove st on cleaned_text
df.loc[:, 'cleaned_text_no_st'] = df.loc[:, 'cleaned_text'].apply(lambda x: remove_st(x))

# remove punctuation and digits
df.loc[:, 'cleaned_text'] = df.loc[:, 'cleaned_text'].apply(lambda x: remove_punctuation_and_digits(x))
df.loc[:, 'cleaned_text_no_st'] = df.loc[:, 'cleaned_text_no_st'].apply(lambda x: remove_punctuation_and_digits(x))

# %%
df
# Out:
#                                                     text  target  \
# 0      LONDON (Reuters) - Britain s government said o...       1
# 1      WASHINGTON (Reuters) - Director of National In...       1
# 2      Former Navy SEAL and GOP Rep. Scott Taylor, R-...       0
# 3      WASHINGTON (Reuters) - The White House on Thur...       1
# 4      BERN (Reuters) - European and African minister...       1
# ...                                                  ...     ...
# 44893  NAIROBI (Reuters) - Burundi s main opposition ...       1
# 44894  This isn t just any church organization, this ...       0
# 44895  Miss Universe 1996 Alicia Machado is now an Am...       0
# 44896                                                          0
# 44897  LONDON/TOKYO (Reuters) - British Prime Ministe...       1
#
#                                             cleaned_text  \
# 0      london reuters  britain government said on thu...
# 1      washington reuters  director of national intel...
# 2      former navy seal and gop rep scott taylor rva ...
# 3      washington reuters  the white house on thursda...
# 4      bern reuters  european and african ministers a...
# ...                                                  ...
# 44893  nairobi reuters  burundi main opposition group...
# 44894  this isn just any church organization this is ...
# 44895  miss universe  alicia machado is now an americ...
# 44896
# 44897  londontokyo reuters  british prime minister th...
#
#                                       cleaned_text_no_st
# 0      london reuters  britain government said thursd...
# 1      washington reuters  director national intellig...
# 2      navy seal gop rep scott taylor rva bodyslammed...
# 3      washington reuters  white house thursday threa...
# 4      bern reuters  european african ministers agree...
# ...                                                  ...
# 44893  nairobi reuters  burundi main opposition group...
# 44894  church organization church organization takes ...
# 44895  miss universe  alicia machado american citizen...
# 44896
# 44897  londontokyo reuters  british prime minister th...
#
# [44898 rows x 4 columns]

# %%
# build a word cloud for target == 0

# Combine all text from the specified column into a single string
text = ' '.join(df[df.target==0]['cleaned_text_no_st'])

# Generate the word cloud
wordcloud = WordCloud(width=800, height=400, background_color='white').generate(text)
# Display the word cloud using matplotlib
plt.figure(figsize=(10, 5))
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis('off')  # Turn off axis labels
plt.show()

# %%
# view the most frequent words for target == 1

# Tokenize the text in the specified column
tokens = []
for text in df[df.target==0]['cleaned_text_no_st']:
    tokens.extend(word_tokenize(text))

# Calculate the frequency distribution of tokens
freq_dist = FreqDist(tokens)

# Display the most frequent words and their counts
most_common_words = freq_dist.most_common(10)
print("Most frequent words:")
for word, count in most_common_words:
    print(f"{word}: {count}")

# Plot a bar chart of the frequency distribution
freq_dist.plot(20, cumulative=False)
plt.show()
# Out:
# Most frequent words:
# trump: 73781
# said: 31016
# people: 25963
# president: 25594
# clinton: 18007
# obama: 17804
# like: 17621
# donald: 17222
# new: 14158
# news: 14134

# %%
# view the most frequent words for target == 1

# Tokenize the text in the specified column
tokens = []
for text in df[df.target==1]['cleaned_text_no_st']:
    tokens.extend(word_tokenize(text))

# Calculate the frequency distribution of tokens
freq_dist = FreqDist(tokens)

# Display the most frequent words and their counts
most_common_words = freq_dist.most_common(10)
print("Most frequent words:")
for word, count in most_common_words:
    print(f"{word}: {count}")

# Plot a bar chart of the frequency distribution
freq_dist.plot(20, cumulative=False)
plt.show()
# Out:
# Most frequent words:
# said: 99039
# trump: 42595
# us: 39395
# reuters: 28404
# president: 25548
# state: 18757
# government: 17980
# states: 17638
# new: 16786
# house: 16407

# %%
CV = CountVectorizer(max_features=15000, dtype=np.int32)

# fit and transform the df
CV.fit(df.cleaned_text_no_st)
transformed_rows = CV.transform(df.cleaned_text_no_st).todense()

# %%
transformed_rows.shape
# Out:
# (44898, 15000)

# %%
# use the three algorithms and build cross validation to assess their performance
# make sure to create one pipeline with a feature selection algorithm inside it as well
import warnings
from sklearn.exceptions import DataConversionWarning
warnings.filterwarnings("ignore", message="Features.*", category=UserWarning)
warnings.filterwarnings("ignore", message="invalid.*", category=RuntimeWarning)
warnings.filterwarnings("ignore", message="A column.*", category=DataConversionWarning)

# Assuming you have your target variable 'y' and features 'transformed_rows'
# Example data
np.random.seed(42)
X = np.asarray(transformed_rows)
y = df.target.values.reshape(-1, 1)

# Create a pipeline with feature selection and classifiers
ridge_pipeline = Pipeline([
    ('feature_selection', SelectKBest(f_classif, k=100)),  # Adjust k as needed
    ('classifier', RidgeClassifier())
])

naive_bayes_pipeline = Pipeline([
    ('feature_selection', SelectKBest(f_classif, k=100)),
    ('classifier', MultinomialNB())
])

linear_svm_pipeline = Pipeline([
    ('feature_selection', SelectKBest(f_classif, k=100)),
    ('classifier', SVC(kernel='linear'))
])

# Define the classifiers
classifiers = {
    'Ridge Classifier': ridge_pipeline,
    'Naive Bayes': naive_bayes_pipeline,
    'Linear SVM': linear_svm_pipeline
}

# Perform cross-validation and compare results
cv = StratifiedKFold(n_splits=5, shuffle=True, random_state=42)

for name, clf in classifiers.items():
    y_pred = cross_val_predict(clf, X, y, cv=cv)

    # Print confusion matrix and metrics
    print(f'\nResults for {name}:')
    print('Confusion Matrix:')
    print(metrics.confusion_matrix(y, y_pred))

    accuracy = metrics.accuracy_score(y, y_pred)
    precision = metrics.precision_score(y, y_pred)
    recall = metrics.recall_score(y, y_pred)
    f1 = metrics.f1_score(y, y_pred)

    print(f'Accuracy: {accuracy:.2f}')
    print(f'Precision: {precision:.2f}')
    print(f'Recall: {recall:.2f}')
    print(f'F1 Score: {f1:.2f}')
# Out:
# Results for Ridge Classifier:
# Confusion Matrix:
# [[23233   248]
#  [  195 21222]]
# Accuracy: 0.99
# Precision: 0.99
# Recall: 0.99
# F1 Score: 0.99
#
# Results for Naive Bayes:
# Confusion Matrix:
# [[21804  1677]
#  [  186 21231]]
# Accuracy: 0.96
# Precision: 0.93
# Recall: 0.99
# F1 Score: 0.96
#
# Results for Linear SVM:
# Confusion Matrix:
# [[23339   142]
#  [   46 21371]]
# Accuracy: 1.00
# Precision: 0.99
# Recall: 1.00
# F1 Score: 1.00
